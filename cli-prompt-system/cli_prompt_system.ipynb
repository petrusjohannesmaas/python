# %% [markdown]
# # Programming Language Capstone
#
# - The primary goals of this project is to encourage healthier programming habits and increase my productivity.
# - I've created my roadmap based on this Youtube video: https://www.youtube.com/watch?v=3QP43F4gVIE

# %% [markdown]
# ## Programmer routine:
#
# ```json
# {
#     "task1":[
#         "Create a research pile for the day.",
#         "25m"
#     ],
#     "task2" :[
#         "Rehydrate immediately.",
#         "5m"
#     ],
#     "task3" :[
#         "Study hard!",
#         "90m"
#     ],
#     "task4" :[
#         "Eat something small... at least.",
#         "15m"
#     ],
#     "task5" :[
#         "Get to work.",
#         "90m"
#     ],
#     "task6" :[
#         "Coffee break.",
#         "5m"
#     ],
#     "task7" :[
#         "Read documentation",
#         "60m"
#     ],
#     "task8" :[
#         "Stretch the legs, it's lunch time!",
#         "30m"
#     ],
#     "task9" :[
#         "Capstone Hackathon is now.",
#         "180m"
#     ],
#     "task10" :[
#         "Take a walk (and rehydrate!)",
#         "180m"
#     ],
#     "task11" :[
#         "Research design pattern of the day",
#         "30m"
#     ],
#     "task12" :[
#         "Shutdown protocol",
#         "shutdown.exe"
#     ],
# }
# ```

# %% [markdown]
# ### Complete roadmap
#
# #### A) Path of the Nerd
# **Boss Quest:** Databases and SQL for Data Science with Python Certificate
# * Development Environment
# * Source Control (Basic)
# * Programming Language
# * Testing
# * API's
# * Back-end Framework
# * Database
# * ORM
# * Retrospect Report
#
# #### Path of the Programmer
# **Boss Quest:** PCEP-30 Certification
# * Notation
# * NoSQL
# * Source control (Advanced)
# * Containerization
# * Monitoring
# * CDN
# * Front End Framework
# * Mobile
# * Retrospect Report
#
# #### Path of the Associate
# **Boss Quest:** PCAP-30 Certification
# * Hosting
# * CI/CD
# * Protocols
# * Distributed Caching
# * Orchestration
# * Cloud Architecture
# * Retrospect Report
#
# #### Path of the Scientist
# **Final Quest:** PCPP-32-1 and PCPP-32-2 Certification
# * Lower Level Language
# * Blockchain
# * Artificial Intelligence
# * Cybersecurity
# * Retrospect Report

# %% [markdown]
# ### Application Demo
#
# #### Welcome
# ```bash
# Hello PJ. Choose your path and start hacking.
#
# [1] NERD (Easy)
# [2] PROGRAMMER (Medium)
# [3] ASSOCIATE (Hard)
# [4] SCIENTIST (Mastery)
#
# Help: type 1, 2, 3 or 4
# ```
#
# #### Path example
# ```bash
# [PATH OF THE NERD]
# Boss quest: Databases and SQL for Data Science with Python Certificate by IBM
#
#     Development Environment
#     Source Control
#     Programming Language
#     Testing
#     API's
#     Back-end Framework
#     Database
#     ORM
#     Retrospect Report
#
#
# Help: | type "next" if done | type "close" to terminate |
# ```
